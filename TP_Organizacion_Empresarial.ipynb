# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Seipel/tp-organizacion-empresarial/blob/main/TP_Organizacion_Empresarial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/S-Seipel/tp-organizacion-empresarial.git
# %cd tp-organizacion-empresarial
# Out:
# Cloning into 'tp-organizacion-empresarial'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 26 (delta 2), reused 18 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 66.87 KiB | 4.78 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/tp-organizacion-empresarial
